# %% [markdown]
# ## iPython Tutorial
#
# #### 5/11/16

# %% [markdown]
# ### Intro to iPython
#     iPython is an advanced interactive Python shell.
#     What that means is that it allows you to interacrively run python code within your web browser
#
#
# ### Where can you download it
#     Follow the guide here: http://jupyter.readthedocs.io/en/latest/install.html
#
#    #### Key Steps:
#         1) Download Anaconda(https://www.continuum.io/downloads)
#         2) Use conda(command line tool from Anaconda) to install Jupyter Notebook + other packages of interest
#
#
# ### How do you run it

# %% [markdown]
# ##### From your terminal window, input "jupyter notebook"
#
# ##### This should open the jupyter interface
#
# ##### Navigate to a folder of your choice and create a new notebook

# %% [markdown]
# ## Useful Commands

# %%
?

# %%
print?

# %%
# %quickref

# %%
##Magic Functions
##Can call with command line syntax
# %cd upstream/
# Out:
# /Users/wgagne-maynard/Dropbox/WGM Data/RESEARCH/TROCAS/TROCAS3/upstream

# %% [markdown]
# #### Tab Completion

# %%
pd.read_csv?

# %% [markdown]
# ### Markdown, images, videos, examples of good online notebooks

# %% [markdown]
# #### Markdown Examples
#
# # 1
# ## 2
# ### 3
# #### 4
#
# * 1
# * 2
# * 3

# %% [markdown]
# ### Showing a local image

# %%
Image(filename="ipython1.png")

# %% [markdown]
# ### Showing a video

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Rc4JQWowG5I')

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.read_csv?

# %% [markdown]
# ### Basic Code section

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
# Out:
# array([ 0.        ,  0.55555556,  1.11111111,  1.66666667,  2.22222222,
#         2.77777778,  3.33333333,  3.88888889,  4.44444444,  5.        ])

# %% [markdown]
# #### Matplotlib

# %%
plt.plot(x,y,'k')
plt.xlabel('xxxxxx')
plt.ylabel('y')
plt.title('example')

# %%
t = np.arange(0., 5., 0.2)

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
# %cd /Users/wgagne-maynard/Dropbox/WGM Data/RESEARCH/TROCAS/TROCAS3/upstream
# %ls
# Out:
# /Users/wgagne-maynard/Dropbox/WGM Data/RESEARCH/TROCAS/TROCAS3/upstream
# ALM to STM.csv                        Upstream_Picarro_notclean
# ALM to STM.xlsx*                      XNG to past ALM.csv
# Obidos Sampling.csv                   XNG to past ALM.xlsx*
# Obidos Sampling.xlsx*                 Xingu Depth and 1 hour upstream.xlsx*
# STM to OBD.csv                        mcp to xng.csv
# STM to OBD.xlsx*                      mcp to xng.xlsx*

# %%
raw = pd.read_csv('ALM to STM.csv')
raw.Datetime = pd.to_datetime(raw.Datetime)

# %%
raw.head(2)
# Out:
#      Date     Time            Datetime     Site Name  Fault Code  Battery V  \
# 0  7/3/15  6:58:33 2015-07-03 06:58:33  Default Site           0        5.4
# 1  7/3/15  6:58:38 2015-07-03 06:58:38  Default Site           0        5.4
#
#    Cable Pwr V    pH  pH mV  ORP mV  ORP raw mV  ODO % sat  ODO mg/L    Temp  \
# 0         11.5  6.33  -14.3  -141.9      -141.9       42.0      3.22  29.126
# 1         11.5  6.33  -14.3  -141.6      -141.6       41.9      3.22  29.128
#
#    Cond  fDOM RFU  fDOM QSU  Press psi a  Depth m
# 0    69    -54.75     63.74        1.054    0.744
# 1    69    -54.72     63.85        1.054    0.744

# %%
raw.shape
# Out:
# (17915, 19)

# %%
raw.describe()
# Out:
#        Fault Code     Battery V  Cable Pwr V            pH         pH mV  \
# count     17915.0  17915.000000  17915.00000  17915.000000  17915.000000
# mean          0.0      5.111649      0.14700      6.537209    -26.478113
# std           0.0      0.092101      1.29189      0.182452     10.782362
# min           0.0      5.000000      0.00000      6.240000    -62.900000
# 25%           0.0      5.000000      0.00000      6.440000    -27.100000
# 50%           0.0      5.100000      0.00000      6.470000    -22.800000
# 75%           0.0      5.200000      0.00000      6.550000    -20.600000
# max           0.0      5.400000     11.50000      7.150000     -8.900000
#
#              ORP mV    ORP raw mV     ODO % sat      ODO mg/L          Temp  \
# count  17915.000000  17915.000000  17915.000000  17915.000000  17915.000000
# mean    -126.738124   -126.738124     72.761317      5.551006     29.420539
# std       11.896163     11.896163     18.722690      1.413609      0.243539
# ...

# %%
plt.figure(figsize=(10,9))
plt.scatter(raw.Cond, raw.pH, edgecolors='', alpha=0.1)
plt.xlabel

# %% [markdown]
# ### Useful Tutorials and Links

# %% [markdown]
# #### [Software Carpentry(UW) Guide to Installation](https://richford.github.io/2015-10-22-uw/#setup)
#
# #### [UW eScience](https://richford.github.io/2015-10-22-uw/#setup)
#     Resources for ipython, python, general programming + data science questions
#
# #### [Collection of Pandas Tutorials](https://github.com/jvns/pandas-cookbook)
#     Collection of ipython tutorials for the pandas data analysis library
#
# #### [Gallery of interesting iPython Notebooks](https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks)
#
# #### [Statsmodels examples](http://statsmodels.sourceforge.net/devel/examples/)
#     Examples of the statsmodels package in use
